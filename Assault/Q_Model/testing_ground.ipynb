# %%
import pathlib 
import sys
parent_dir = pathlib.Path.cwd().parent.parent
sys.path.append(str(parent_dir))
import Q_Model.training as tr
import Q_Model.agent as agent
import importlib
importlib.reload(tr)
# Out:
# <module 'Q_Model.training' from '/home/cody/Documents/DataSciBC/GameRFL/Q_Model/training.py'>

# %%
assault = tr.training('ALE/Assault-v5',learning_rate = 0.01,n_episodes=100,start_epsilon=1,final_epsilon=0.1)
assault.train()
assault.training_metrics()
# Out:
# 100%|██████████| 100/100 [01:03<00:00,  1.57it/s]
# <RecordEpisodeStatistics<OrderEnforcing<PassiveEnvChecker<AtariEnv<ALE/Assault-v5>>>>>
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
assault_agent = assault.agent
assault_agent.run_agent('ALE/Assault-v5')
# Out:
# initial: ((np.uint8(0),), (np.uint8(0),), (np.uint8(0),), (np.uint8(0),), (np.uint8(0),), (np.uint8(0),), (np.uint8(0),), (np.uint8(0),), (np.uint8(0),), (np.uint8(0),), (np.uint8(0),), (np.uint8(96),), (np.uint8(254),), (np.uint8(0),), (np.uint8(0),), (np.uint8(0),), (np.uint8(6),), (np.uint8(100),), (np.uint8(100),), (np.uint8(100),), (np.uint8(0),), (np.uint8(0),), (np.uint8(0),), (np.uint8(0),), (np.uint8(88),), (np.uint8(254),), (np.uint8(0),), (np.uint8(0),), (np.uint8(192),), (np.uint8(0),), (np.uint8(136),), (np.uint8(252),), (np.uint8(2),), (np.uint8(2),), (np.uint8(2),), (np.uint8(2),), (np.uint8(130),), (np.uint8(130),), (np.uint8(130),), (np.uint8(6),), (np.uint8(188),), (np.uint8(255),), (np.uint8(0),), (np.uint8(25),), (np.uint8(0),), (np.uint8(253),), (np.uint8(0),), (np.uint8(253),), (np.uint8(128),), (np.uint8(64),), (np.uint8(128),), (np.uint8(128),), (np.uint8(64),), (np.uint8(128),), (np.uint8(0),), (np.uint8(0),), (np.uint8(0),), (np.uint8(0),), (np.uint8(0),), (
# ...
