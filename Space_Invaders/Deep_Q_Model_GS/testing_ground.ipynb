# %%
import pathlib
import sys
parentdir = pathlib.Path.cwd().parent.parent
sys.path.append(str(parentdir))
import Space_Invaders.Deep_Q_Model_GS.training as trainer
import Space_Invaders.Deep_Q_Model_GS.agent as agent

import os
file = os.getcwd()
print(file)
# Out:
# /home/cody/Documents/DataSciBC/GameRFL/Space_Invaders/Deep_Q_Model_GS

# %%
si_trainer = trainer.SI_training('test',n_episodes=10,update_factor=5)
si_trainer.train()
# Out:
# A.L.E: Arcade Learning Environment (version 0.10.1+unknown)
# [Powered by Stella]
# episode 0
# cumulative reward: 20.031342111089195
# 1.0
# episode 1
# episode 1 with loss 0.0034140271600335836
# episode 1 with loss 0.04557246342301369
# cumulative reward: 9.641533250824976
# 0.91
# episode 2
# episode 2 with loss 0.004533562809228897
# episode 2 with loss 0.003104686737060547
# cumulative reward: 3.238442939043138
# 0.8200000000000001
# episode 3
# episode 3 with loss 0.0057998537085950375
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 2
#       1 si_trainer = trainer.SI_training('test',n_episodes=10,update_factor=5)
# ----> 2 si_trainer.train()
#
# File ~/Documents/DataSciBC/GameRFL/Deep_Q_Learning_GrayScale/training.py:135, in Q_training.train(self)
#     131 update_target+=1
#     133 if len(self.replay_buffer)>1000:
# ...

# %%
si_trainer.results()
si_trainer.save()

# %%
si_trainer.agent.run_agent()
