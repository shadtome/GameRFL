# %%
import pathlib
import sys
parentdir = pathlib.Path.cwd().parent.parent
sys.path.append(str(parentdir))
import Deep_Q_Learning.training as trainer
import Space_Invaders.Deep_Q_Model.agent as agent

import os
file = os.getcwd()
print(file)
# Out:
# /home/cody/Documents/DataSciBC/GameRFL/Space_Invaders/Deep_Q_Model

# %%
test_agent = agent.SI_Agent()
test_agent.load('test')
test_agent.run_agent()
# Out:
# A.L.E: Arcade Learning Environment (version 0.10.1+unknown)
# [Powered by Stella]
# ...

# %%
filepath = 'test_1'
SI_train = trainer.Q_training(agent_cl=agent.SI_Agent,n_episodes=5,start_epsilon=1,final_epsilon=0.1,filepath=filepath,update_factor=100)
#SI_train.load()
SI_train.train()
# Out:
# A.L.E: Arcade Learning Environment (version 0.10.1+unknown)
# [Powered by Stella]
# episode 0
# cumulative reward: 535.0
# 1.0
# episode 1
# episode 1 with loss 12.216409683227539
# episode 1 with loss 458880.1875
# episode 1 with loss 122.83953857421875
# cumulative reward: 175.0
# 0.8200000000000001
# episode 2
# episode 2 with loss 14.124238967895508
# episode 2 with loss 18.89654541015625
# episode 2 with loss 0.1599690020084381
# episode 2 with loss 3.7459523677825928
# episode 2 with loss 9.26903247833252
# cumulative reward: 240.0
# 0.64
# episode 3
# episode 3 with loss 10.236820220947266
# episode 3 with loss 20.873353958129883
# episode 3 with loss 0.5698535442352295
# episode 3 with loss 10.295475959777832
# episode 3 with loss 1.5948387384414673
# cumulative reward: 355.0
# 0.45999999999999996
# episode 4
# episode 4 with loss 0.4782918393611908
# episode 4 with loss 8.802180290222168
# episode 4 with loss 0.24605199694633484
# episode 4 with loss 0.47309210896492004
# ...

# %%
SI_train.results()
si_agent = SI_train.agent

# %%
si_agent.run_agent()
# Out:
# cumulative reward: 6065.0

# %%
#si_agent.save('test2')

# %%
testing = trainer.Q_training()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 testing = trainer.Q_training()
#
# TypeError: Q_training.__init__() missing 2 required positional arguments: 'agent_cl' and 'filepath'
