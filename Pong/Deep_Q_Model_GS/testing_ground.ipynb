# %%
import pathlib
import sys
parentdir = pathlib.Path.cwd().parent.parent
sys.path.append(str(parentdir))
import Pong.Deep_Q_Model_GS.training as trainer
import Pong.Deep_Q_Model_GS.agent as agent

import os
file = os.getcwd()
print(file)
# Out:
# /home/cody/Documents/DataSciBC/GameRFL/Pong/Deep_Q_Model_GS

# %%
Pong_GS_trainer = trainer.Pong_training('gs_test',n_episodes=100,update_factor=640)
Pong_GS_trainer.train()
# Out:
# A.L.E: Arcade Learning Environment (version 0.10.1+unknown)
# [Powered by Stella]
# episode 0
# cumulative reward: -12.812264220437765
# 1.0
# episode 1
# tensor([2, 3, 5, 1, 3, 1, 3, 3, 5, 3, 4, 2, 3, 3, 5, 0, 5, 0, 5, 2, 2, 0, 3, 2,
#         5, 0, 5, 4, 0, 3, 4, 4, 3, 5, 0, 5, 3, 0, 2, 5, 0, 1, 1, 4, 5, 1, 1, 1,
#         4, 5, 4, 3, 2, 1, 0, 2, 1, 4, 3, 2, 1, 1, 0, 2])
# episode 1 with loss 0.018474681302905083
# tensor([5, 1, 4, 2, 0, 5, 1, 2, 3, 4, 1, 3, 0, 3, 1, 5, 3, 4, 4, 0, 0, 2, 0, 1,
#         5, 0, 4, 0, 5, 5, 5, 3, 1, 0, 1, 1, 4, 5, 2, 0, 0, 4, 0, 3, 3, 4, 0, 3,
#         2, 1, 3, 1, 4, 0, 1, 1, 5, 4, 3, 2, 3, 5, 2, 3])
# tensor([0, 0, 0, 3, 1, 5, 2, 4, 0, 2, 1, 4, 0, 2, 1, 0, 0, 1, 5, 4, 4, 3, 1, 3,
#         1, 2, 1, 4, 5, 2, 1, 1, 3, 0, 3, 0, 0, 5, 3, 5, 5, 3, 1, 4, 0, 0, 1, 2,
#         2, 0, 1, 5, 5, 3, 2, 5, 4, 0, 0, 1, 0, 5, 0, 4])
# episode 1 with loss 339453.5625
# tensor([0, 3, 4, 4, 1, 5, 2, 5, 0, 2, 3, 3, 3, 0, 2, 3, 3, 3, 5, 1, 5, 1, 3, 5,
# ...

# %%
Pong_GS_trainer.results()
Pong_GS_trainer.save()
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
Pong_GS_trainer.agent.run_agent()
