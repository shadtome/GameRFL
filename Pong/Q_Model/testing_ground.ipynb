# %%
import pathlib 
import sys
parent_dir = pathlib.Path.cwd().parent.parent
sys.path.append(str(parent_dir))
import Space_Invaders.Q_Model.training as tr
import importlib
importlib.reload(tr)
# Out:
# <module 'Space_Invaders.Q_Model.training' from '/home/cody/Documents/DataSciBC/GameRFL/Space_Invaders/Q_Model/training.py'>

# %%
SI = tr.Space_Invaders_training('ALE/SpaceInvaders-v5',learning_rate = 0.0001,n_episodes=1000,start_epsilon=0.97,final_epsilon=0.3,
                                discount_factor=0.99)
SI.train()
SI.training_metrics()
# Out:
# A.L.E: Arcade Learning Environment (version 0.10.1+unknown)
# [Powered by Stella]
# 100%|██████████| 1000/1000 [05:40<00:00,  2.94it/s]
# <RecordEpisodeStatistics<Space_Invaders_Rewards<NormalizeReward<OrderEnforcing<PassiveEnvChecker<AtariEnv<ALE/SpaceInvaders-v5>>>>>>>

# %%
SI_agent = SI.agent

SI_agent.run_agent('ALE/SpaceInvaders-v5')
# Out:
# initial: ((np.uint8(0),), (np.uint8(7),), (np.uint8(0),), (np.uint8(68),), (np.uint8(241),), (np.uint8(162),), (np.uint8(34),), (np.uint8(183),), (np.uint8(68),), (np.uint8(13),), (np.uint8(124),), (np.uint8(255),), (np.uint8(255),), (np.uint8(50),), (np.uint8(255),), (np.uint8(255),), (np.uint8(0),), (np.uint8(36),), (np.uint8(63),), (np.uint8(63),), (np.uint8(63),), (np.uint8(63),), (np.uint8(63),), (np.uint8(63),), (np.uint8(82),), (np.uint8(0),), (np.uint8(23),), (np.uint8(43),), (np.uint8(35),), (np.uint8(117),), (np.uint8(180),), (np.uint8(0),), (np.uint8(36),), (np.uint8(63),), (np.uint8(63),), (np.uint8(63),), (np.uint8(63),), (np.uint8(63),), (np.uint8(63),), (np.uint8(110),), (np.uint8(0),), (np.uint8(23),), (np.uint8(1),), (np.uint8(60),), (np.uint8(126),), (np.uint8(126),), (np.uint8(126),), (np.uint8(126),), (np.uint8(255),), (np.uint8(255),), (np.uint8(255),), (np.uint8(195),), (np.uint8(60),), (np.uint8(126),), (np.uint8(126),), (np.uint8(126),), (np.uint8(126),), (np.
# ...
